# %% [markdown]
# <a href="https://colab.research.google.com/github/Sibu07/telegram_bot/blob/main/final_telegram_bot_username.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BOT_USER_NAME

# %%
import requests

# Take input from the user for BOT_TOKEN
BOT_TOKEN = input("Enter your bot token: ")

bot_info_url = f"https://api.telegram.org/bot{BOT_TOKEN}/getMe"

response = requests.get(bot_info_url)
data = response.json()

if data["ok"]:
    bot_username = data["result"]["username"]
    print(f"Bot username: @{bot_username}")
else:
    print("Failed to retrieve bot information")
# Out:
# Enter your bot token: 6588800682:AAH7UrKH_8XgSc0IW_8BvMzI4ykNum9QlXc
# Bot username: @GTMMirrorZBot

# %% [markdown]
# # MongoDB_DATA_get

# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 36.2 MB/s eta 0:00:00
# ...

# %%
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = input("Enter your MongoDB connection URL: ")
#mongo_url = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://wzmlmovie:wzmlmovie@apnatube.9zwre6z.mongodb.net/?retryWrites=true&w=majority"
# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# List all the databases in your cluster
all_databases = client.list_database_names()

# Iterate through the databases and list their collections
for db_name in all_databases:
    db = client[db_name]
    collections = db.list_collection_names()
    print(f"Database: {db_name}")
    print(f"Collections: {collections}")
# Out:
# Enter your bot token: mongodb+srv://gtm:gtm@cluster0.kv3pvje.mongodb.net/?retryWrites=true&w=majority
# Database: z
# Collections: ['settings.config', 'settings.files', 'users.6588800682', 'settings.aria2c', 'settings.qbittorrent']
# Database: admin
# Collections: []
# Database: local
# Collections: ['oplog.rs']

# %%
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://a1:a1@cluster0.0pola4b.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://wzmlmovie:wzmlmovie@apnatube.9zwre6z.mongodb.net/?retryWrites=true&w=majority"
#m = "mongodb+srv://gtm:gtm@cluster0.kv3pvje.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://wzmlmovie:wzmlmovie@apnatube.9zwre6z.mongodb.net/wzmlx"

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# Access your database
db = client['wzmlx']  # Replace 'wzmlx' with your actual database name

# List all the collections in the database
collections = db.list_collection_names()

# Iterate through the collections and retrieve data from each one
for collection_name in collections:
    collection = db[collection_name]
    all_documents = collection.find()

    # Print the documents from the current collection
    print(f"Collection: {collection_name}")
    for document in all_documents:
        print(document)
# Out:
# Collection: settings.aria2c
# ...

# %% [markdown]
# # MongoDB_DATA_update

# %%
import pymongo

# Replace this connection string with your actual MongoDB connection string
#mongo_uri = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/wzmlx"
#mongo_uri = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/wzmlx"
#mongo_url = "mongodb+srv://wzmlmovie:wzmlmovie@apnatube.9zwre6z.mongodb.net/wzmlx"
mongo_url = input("Enter your MongoDB connection URL: ")

# Create a MongoDB client
client = pymongo.MongoClient(mongo_url)

# Specify the database where you want to create the collection
db = client.get_database()
collection_name = "Data"

# Create the new collection (it will be created if it doesn't exist)
db.create_collection(collection_name)
# Close the connection
client.close()

print(f"Collection '{collection_name}' has been created.")
# Out:
# Enter your MongoDB connection URL: mongodb+srv://gtm:gtm@cluster0.kv3pvje.mongodb.net/z
# Collection 'Data' has been created.

# %%
import pymongo

# Replace this connection string with your actual MongoDB connection string
#mongo_uri = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/wzmlx"
mongo_uri = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/wzmlx"

# Create a MongoDB client
client = pymongo.MongoClient(mongo_uri)

# Specify the database and collection you want to update
db = client.get_database()
collection_name = "users.6368645583"
#collection_name = "pm_users.6368645583"


# Define the new document you want to insert
new_document = {'_id': 1881720028, 'is_sudo': True, 'is_auth': True}

# Use update_one to add the new document if it doesn't exist
db[collection_name].update_one({'_id': new_document['_id']}, {'$set': new_document}, upsert=True)

# Close the connection
client.close(

print(f"New document has been added to collection '{collection_name}'.")
# Out:
#   File "<ipython-input-9-1eb718f706a6>", line 25
#     print(f"New document has been added to collection '{collection_name}'.")
#                                                                             ^
# SyntaxError: incomplete input

# %%
import pymongo

# Replace the URL with your MongoDB connection string
#mongo_url = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://a1:a1@cluster0.0pola4b.mongodb.net/?retryWrites=true&w=majority"
mongo_url = "mongodb+srv://s1:s1@cluster1.egkszqq.mongodb.net/?retryWrites=true&w=majority"
# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# Access your database
db = client['wzmlx']  # Replace 'wzmlx' with your actual database name

# List all the collections in the database
collections = db.list_collection_names()

# Iterate through the collections and retrieve data from each one
for collection_name in collections:
    collection = db[collection_name]
    all_documents = collection.find()

    # Print the documents from the current collection
    print(f"Collection: {collection_name}")
    for document in all_documents:
        print(document)
# Out:
# Collection: settings.qbittorrent
# ...

# %%
import pymongo

# Replace the URL with your MongoDB connection string
#mongo_url = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/?retryWrites=true&w=majority"
#mongo_url = "mongodb+srv://a1:a1@cluster0.0pola4b.mongodb.net/?retryWrites=true&w=majority"
mongo_url = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/?retryWrites=true&w=majority"

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# List all the databases in your cluster
all_databases = client.list_database_names()

# Iterate through the databases and list their collections
for db_name in all_databases:
    db = client[db_name]
    collections = db.list_collection_names()
    print(f"Database: {db_name}")
    print(f"Collections: {collections}")
# Out:
# Database: wzmlx
# Collections: ['settings.aria2c', 'users.6368645583', 'pm_users.6368645583', 'tasks.6368645583', 'settings.config', 'settings.files', 'settings.deployConfig', 'settings.qbittorrent']
# Database: admin
# Collections: []
# Database: local
# Collections: ['oplog.rs']

# %%
import pymongo

# Replace this connection string with your actual MongoDB connection string
#mongo_uri = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/wzmlx"
#mongo_uri = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/?retryWrites=true&w=majority"
mongo_url = "mongodb+srv://wzmlmovie:wzmlmovie@apnatube.9zwre6z.mongodb.net/wzmlx"


# Create a MongoDB client
client = pymongo.MongoClient(mongo_url)

# Specify the database and collection you want to update
db = client.get_database()
collection_name = "settings.deployConfig"

# Define the new value for 'AUTHORIZED_CHATS'
new_value = '1881720028'

# Update the document in the collection
db[collection_name].update_one({}, {'$set': {'SUDO_USERS': new_value}})

# Close the connection
client.close()

print(f"'AUTHORIZED_CHATS' in collection '{collection_name}' has been updated to '{new_value}'.")
# Out:
# 'AUTHORIZED_CHATS' in collection 'settings.deployConfig' has been updated to '1881720028'.

# %%
import pymongo

# Replace the old connection string with the new one
mongo_uri = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/wzmlx"

# Create a MongoDB client
client = pymongo.MongoClient(mongo_uri)

# Specify the database and collection you want to add a document to
db = client.get_database()
collection_name = "users.6368645583"

# Define the new document you want to insert
new_document = {'_id': 1881720028, 'is_sudo': True}

# Insert the new document into the collection
db[collection_name].insert_one(new_document)

# Specify the collection you want to update
collection_name = "settings.deployConfig"

# Define the new value for 'AUTHORIZED_CHATS'
new_value = '1881720028'

# Update the document in the collection
db[collection_name].update_one({}, {'$set': {'SUDO_USERS': new_value}})

# Close the connection
client.close()

print(f"New document {_id} has been added to collection 'users.6026438512'.")
print(f"'AUTHORIZED_CHATS' in collection 'settings.config' has been updated to '{new_value}'.")
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-33-b1169aad621e> in <cell line: 17>()
#      15
#      16 # Insert the new document into the collection
# ---> 17 db[collection_name].insert_one(new_document)
#      18
#      19 # Specify the collection you want to update
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     669         write_concern = self._write_concern_for(session)
#     670         return InsertOneResult(
# --> 671             self._insert_one(
#     672                 document,
#     673                 ordered=True,
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     609             _check_write_command_response(result)
#     610
# ...

# %%
import pymongo

# Replace this connection string with your actual MongoDB connection string
#mongo_uri = "mongodb+srv://wzmlporn:wzmlporn@apnatube.12njhhm.mongodb.net/wzmlx"
mongo_url = "mongodb+srv://wzmlmovie:wzmlmovie@apnatube.9zwre6z.mongodb.net/wzmlx"

# Create a MongoDB client
client = pymongo.MongoClient(mongo_url)

# Specify the database and collection you want to update
db = client.get_database()
collection_name = "users.6351581522"  # Replace with the actual collection name

# Define the new document you want to insert
new_document = {'_id': 1881720028, 'is_sudo': True, 'is_auth': True}

# Use update_one to add the new document if it doesn't exist
db[collection_name].update_one({'_id': new_document['_id']}, {'$set': new_document}, upsert=True)

# Close the connection
client.close()

print(f"New document has been added to collection '{collection_name}'.")
# Out:
# New document has been added to collection 'users.6351581522'.

# %% [markdown]
# # Delete whole data from Database

# %%
import pymongo

# Prompt the user for the MongoDB connection URL
mongo_url = input("Enter your MongoDB connection URL: ")

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# Prompt the user for the name of the new database
new_database_name = input("Enter the name of the new database: ")

# Access the new database or create it if it doesn't exist
new_db = client[new_database_name]

# Confirm the creation of the new database
print(f"Database '{new_database_name}' has been created.")

# %%
import pymongo

# Prompt the user for the MongoDB connection URL
mongo_url = input("Enter your MongoDB connection URL: ")

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# List all the database names in the MongoDB server
database_names = client.list_database_names()

# Iterate through the database names and list their collections
for database_name in database_names:
    # Access the current database
    db = client[database_name]

    # List all the collections in the current database
    collection_names = db.list_collection_names()

    # Print the current database name
    print(f"Database: {database_name}")

    # Print the collections in the current database
    for collection_name in collection_names:
        print(f"  Collection: {collection_name}")
# Out:
# Enter your MongoDB connection URL: mongodb+srv://gtm:gtm@cluster0.kv3pvje.mongodb.net/?retryWrites=true&w=majority
# Database: z
#   Collection: settings.config
#   Collection: settings.files
#   Collection: users.6588800682
#   Collection: settings.aria2c
#   Collection: settings.qbittorrent
# Database: admin
# Database: local
#   Collection: oplog.rs

# %%
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = input("Enter your MongoDB connection URL: ")

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# List all the databases in your cluster
all_databases = client.list_database_names()

# Iterate through the databases and list their collections
for db_name in all_databases:
    db = client[db_name]
    collections = db.list_collection_names()
    print(f"Database: {db_name}")
    print(f"Collections: {collections}")
# Out:
# Enter your bot token: mongodb+srv://gtm:gtm@cluster0.kv3pvje.mongodb.net/?retryWrites=true&w=majority
# Database: z
# Collections: ['settings.config', 'settings.files', 'users.6588800682', 'settings.aria2c', 'settings.qbittorrent']
# Database: admin
# Collections: []
# Database: local
# Collections: ['oplog.rs']

# %% [markdown]
# # **Z_MIRROR**
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
# @title **Use for create Database name & Collection name**
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = input("Enter your MongoDB connection URL: ")

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# List all the databases in your cluster
all_databases = client.list_database_names()

# Iterate through the databases and list their collections
for db_name in all_databases:
    db = client[db_name]
    collections = db.list_collection_names()
    print(f"Database: {db_name}")
    print(f"Collections: {collections}")

# %%
# @title **Use to get the whole Database**
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = input("Enter your MongoDB connection URL: ")
# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# Access your database
db = client['z']  # Replace 'wzmlx' with your actual database name

# List all the collections in the database
collections = db.list_collection_names()

# Iterate through the collections and retrieve data from each one
for collection_name in collections:
    collection = db[collection_name]
    all_documents = collection.find()

    # Print the documents from the current collection
    print(f"Collection: {collection_name}")
    for document in all_documents:
        print(document)

# %%
# @title **Use update the value in document**
import pymongo

# Replace this connection string with your actual MongoDB connection string
#mongo_uri = "mongodb+srv://gtm:gtm@cluster0.nfwfz8s.mongodb.net/wzmlx"
mongo_uri = input("Enter your MongoDB connection URL: ")

# Create a MongoDB client
client = pymongo.MongoClient(mongo_uri)

# Specify the database and collection you want to update
db = client.get_database()
collection_name = input("Enter The Collection Name You want To upload: ")
#collection_name = "pm_users.6368645583"


# Define the new document you want to insert
new_document = {'_id': 1881720028, 'is_sudo': True, 'is_auth': True}

# Use update_one to add the new document if it doesn't exist
db[collection_name].update_one({'_id': new_document['_id']}, {'$set': new_document}, upsert=True)

# Close the connection
client.close()

# Print a success message
print("New document has been added to collection.")

# %% [markdown]
# # **WZML-X**
#
#
#
# ---
#
#
#
# ---

# %%
# @title **Use for create Database name & Collection name**
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = input("Enter your MongoDB connection URL: ")

# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# List all the databases in your cluster
all_databases = client.list_database_names()

# Iterate through the databases and list their collections
for db_name in all_databases:
    db = client[db_name]
    collections = db.list_collection_names()
    print(f"Database: {db_name}")
    print(f"Collections: {collections}")

# %%
# @title **Use to get the whole Database**
import pymongo

# Replace the URL with your MongoDB connection string
mongo_url = input("Enter your MongoDB connection URL: ")
# Create a MongoClient
client = pymongo.MongoClient(mongo_url)

# Access your database
db = client['wzmlx']  # Replace 'wzmlx' with your actual database name

# List all the collections in the database
collections = db.list_collection_names()

# Iterate through the collections and retrieve data from each one
for collection_name in collections:
    collection = db[collection_name]
    all_documents = collection.find()

    # Print the documents from the current collection
    print(f"Collection: {collection_name}")
    for document in all_documents:
        print(document)

# %%
# @title **Use update the value in document**
import pymongo

# Replace this connection string with your actual MongoDB connection string
mongo_uri = input("Enter your MongoDB connection URL: ")

# Create a MongoDB client
client = pymongo.MongoClient(mongo_uri)

# Specify the database and collection you want to update
db = client.get_database()
collection_name = input("Enter The Collection Name You want To upload: ")


# Define the new document you want to insert
new_document = {'_id': 1881720028, 'is_sudo': True, 'is_auth': True}

# Use update_one to add the new document if it doesn't exist
db[collection_name].update_one({'_id': new_document['_id']}, {'$set': new_document}, upsert=True)

# Close the connection
client.close()

# Print a success message
print("New document has been added to collection.")
